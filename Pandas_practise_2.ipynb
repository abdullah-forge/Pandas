# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullah-forge/Pandas/blob/main/Pandas_practise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
coffee = pd.read_csv("coffee_sales.csv")
coffee
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price_Per_Cup  \
# 0      1001      Ali      Lahore       Latte   Small         2            450
# 1      1002     Sara     Karachi    Espresso  Medium         1            350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3            500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2            550
# 4      1005   Hassan      Multan   Americano   Large         4            400
# 5      1006   Zainab      Lahore       Latte  Medium         1            450
# 6      1007    Usman     Karachi    Espresso   Small         5            350
# 7      1008   Maryam   Islamabad  Flat White   Large         2            600
# 8      1009    Bilal    Peshawar  Cappuccino   Small         3            500
# 9      1010   Fatima      Quetta       Mocha  Medium         2            550
#
#    Discount
# 0        20
# 1         0
# 2        30
# 3        25
# 4        40
# 5        10
# 6        50
# 7        30
# 8        20
# 9        25

# %%
coffee.head()
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price_Per_Cup  \
# 0      1001      Ali      Lahore       Latte   Small         2            450
# 1      1002     Sara     Karachi    Espresso  Medium         1            350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3            500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2            550
# 4      1005   Hassan      Multan   Americano   Large         4            400
#
#    Discount
# 0        20
# 1         0
# 2        30
# 3        25
# 4        40

# %%
coffee.columns
# Out:
# Index(['Order_ID', 'Customer', 'City', 'Coffee_Type', 'Size', 'Quantity',
#        'Price_Per_Cup', 'Discount'],
#       dtype='object')

# %%
# droping column
coffee = coffee.drop("Discount", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_780/1208643112.py in <cell line: 0>()
#       1 # droping column
# ----> 2 coffee = coffee.drop("Discount", axis=1)
#       3 coffee.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Discount'] not found in axis"

# %%
coffee.head()
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price_Per_Cup
# 0      1001      Ali      Lahore       Latte   Small         2            450
# 1      1002     Sara     Karachi    Espresso  Medium         1            350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3            500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2            550
# 4      1005   Hassan      Multan   Americano   Large         4            400

# %%
# rename column
coffee = coffee.rename(columns={
    "Price_Per_Cup" : "Price"
})

# %%
coffee.head()
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price
# 0      1001      Ali      Lahore       Latte   Small         2    450
# 1      1002     Sara     Karachi    Espresso  Medium         1    350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3    500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2    550
# 4      1005   Hassan      Multan   Americano   Large         4    400

# %%
# creating new column and column multiplication
coffee["Total"] = coffee["Quantity"] * coffee["Price"]

# %%
coffee.head()
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price  Total
# 0      1001      Ali      Lahore       Latte   Small         2    450    900
# 1      1002     Sara     Karachi    Espresso  Medium         1    350    350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3    500   1500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2    550   1100
# 4      1005   Hassan      Multan   Americano   Large         4    400   1600

# %%
#save specific column
customer_bill = coffee[["Customer", "Total"]]

# %%
customer_bill
# Out:
#   Customer  Total
# 0      Ali    900
# 1     Sara    350
# 2    Ahmed   1500
# 3   Ayesha   1100
# 4   Hassan   1600
# 5   Zainab    450
# 6    Usman   1750
# 7   Maryam   1200
# 8    Bilal   1500
# 9   Fatima   1100

# %%
customer_bill.to_csv("customer>bill.csv", index=False)

# %%
suppliers = pd.read_csv("coffee_suppliers.csv")

# %%
suppliers.head()
# Out:
#   Supplier_ID Coffee_Type   Supplier_Name   Country
# 0        S101       Latte    Bean Masters    Brazil
# 1        S102    Espresso      Black Gold  Colombia
# 2        S103  Cappuccino  Mountain Beans  Ethiopia
# 3        S104       Mocha   Premium Roast     Kenya
# 4        S105   Americano    Coffee World   Vietnam

# %%
merge = pd.merge(
    coffee,suppliers, on="Coffee_Type"
)

# %%
merge
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price  Total  \
# 0      1001      Ali      Lahore       Latte   Small         2    450    900
# 1      1002     Sara     Karachi    Espresso  Medium         1    350    350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3    500   1500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2    550   1100
# 4      1005   Hassan      Multan   Americano   Large         4    400   1600
# 5      1006   Zainab      Lahore       Latte  Medium         1    450    450
# 6      1007    Usman     Karachi    Espresso   Small         5    350   1750
# 7      1008   Maryam   Islamabad  Flat White   Large         2    600   1200
# 8      1009    Bilal    Peshawar  Cappuccino   Small         3    500   1500
# 9      1010   Fatima      Quetta       Mocha  Medium         2    550   1100
#
#   Supplier_ID   Supplier_Name    Country
# 0        S101    Bean Masters     Brazil
# 1        S102      Black Gold   Colombia
# 2        S103  Mountain Beans   Ethiopia
# 3        S104   Premium Roast      Kenya
# 4        S105    Coffee World    Vietnam
# 5        S101    Bean Masters     Brazil
# 6        S102      Black Gold   Colombia
# 7        S106    Elite Coffee  Indonesia
# 8        S103  Mountain Beans   Ethiopia
# 9        S104   Premium Roast      Kenya

# %%
branches = pd.read_csv("coffee_branches.csv")

# %%
coffee_branches = pd.merge(
    coffee, branches, on="City"
)

# %%
coffee_branches
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price  Total  \
# 0      1001      Ali      Lahore       Latte   Small         2    450    900
# 1      1002     Sara     Karachi    Espresso  Medium         1    350    350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3    500   1500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2    550   1100
# 4      1005   Hassan      Multan   Americano   Large         4    400   1600
# 5      1006   Zainab      Lahore       Latte  Medium         1    450    450
# 6      1007    Usman     Karachi    Espresso   Small         5    350   1750
# 7      1008   Maryam   Islamabad  Flat White   Large         2    600   1200
# 8      1009    Bilal    Peshawar  Cappuccino   Small         3    500   1500
# 9      1010   Fatima      Quetta       Mocha  Medium         2    550   1100
#
#   Branch_ID Manager
# 0       B01  Kamran
# 1       B02    Hina
# 2       B03   Usama
# 3       B04    Nida
# 4       B05   Hamza
# 5       B01  Kamran
# 6       B02    Hina
# 7       B03   Usama
# 8       B06   Saqib
# 9       B07    Amna

# %%
new_orders = pd.read_csv("new_orders.csv")

# %%
#concatenating
all_orders = pd.concat([coffee, new_orders], ignore_index = True)

# %%
all_orders
# Out:
#     Order_ID Customer        City Coffee_Type    Size  Quantity  Price  \
# 0       1001      Ali      Lahore       Latte   Small         2  450.0
# 1       1002     Sara     Karachi    Espresso  Medium         1  350.0
# 2       1003    Ahmed   Islamabad  Cappuccino   Large         3  500.0
# 3       1004   Ayesha  Faisalabad       Mocha  Medium         2  550.0
# 4       1005   Hassan      Multan   Americano   Large         4  400.0
# 5       1006   Zainab      Lahore       Latte  Medium         1  450.0
# 6       1007    Usman     Karachi    Espresso   Small         5  350.0
# 7       1008   Maryam   Islamabad  Flat White   Large         2  600.0
# 8       1009    Bilal    Peshawar  Cappuccino   Small         3  500.0
# 9       1010   Fatima      Quetta       Mocha  Medium         2  550.0
# 10      1011     Noor      Lahore       Latte   Large         2    NaN
# 11      1012     Saad     Karachi       Mocha   Small         1    NaN
# 12      1013     Eman   Islamabad    Espresso  Medium         3    NaN
#
#      Total  Price_Per_Cup  Discount
# 0    900.0            NaN       NaN
# 1    350.0            NaN       NaN
# 2   1500.0            NaN       NaN
# 3   1100.0            NaN       NaN
# 4   1600.0            NaN       NaN
# 5    450.0            NaN       NaN
# 6   1750.0            NaN       NaN
# 7   1200.0            NaN       NaN
# 8   1500.0            NaN       NaN
# 9   1100.0            NaN       NaN
# 10     NaN          450.0      20.0
# 11     NaN          550.0      10.0
# 12     NaN          350.0      30.0

# %%
# combine
combined = coffee.join(branches.set_index("City"), on="City")

# %%
combined
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price  Total  \
# 0      1001      Ali      Lahore       Latte   Small         2    450    900
# 1      1002     Sara     Karachi    Espresso  Medium         1    350    350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3    500   1500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2    550   1100
# 4      1005   Hassan      Multan   Americano   Large         4    400   1600
# 5      1006   Zainab      Lahore       Latte  Medium         1    450    450
# 6      1007    Usman     Karachi    Espresso   Small         5    350   1750
# 7      1008   Maryam   Islamabad  Flat White   Large         2    600   1200
# 8      1009    Bilal    Peshawar  Cappuccino   Small         3    500   1500
# 9      1010   Fatima      Quetta       Mocha  Medium         2    550   1100
#
#   Branch_ID Manager
# 0       B01  Kamran
# 1       B02    Hina
# 2       B03   Usama
# 3       B04    Nida
# 4       B05   Hamza
# 5       B01  Kamran
# 6       B02    Hina
# 7       B03   Usama
# 8       B06   Saqib
# 9       B07    Amna

# %%
combined.to_csv("final_coffee_data.csv",index=False)

# %%
quantity = coffee.loc[0,"Quantity"]
if quantity > 2:
  print("Large Order")
else:
  print("Small order")
# Out:
# Small order

# %%
#using for loop
for qty in coffee["Quantity"]:
  if qty > 3:
    print("Bulk Order")
  else:
    print("Small Order")
# Out:
# Small Order
# Small Order
# Small Order
# Small Order
# Bulk Order
# Small Order
# Bulk Order
# Small Order
# Small Order
# Small Order

# %%
#creating new column using if else
order_type = []
for qty in coffee["Quantity"]:
  if qty > 3:
    order_type.append("Bulk Order")
  else:
    order_type.append("Small Order")

# %%
coffee["Order Type"] = order_type

# %%
coffee
# Out:
#    Order_ID Customer        City Coffee_Type    Size  Quantity  Price  Total  \
# 0      1001      Ali      Lahore       Latte   Small         2    450    900
# 1      1002     Sara     Karachi    Espresso  Medium         1    350    350
# 2      1003    Ahmed   Islamabad  Cappuccino   Large         3    500   1500
# 3      1004   Ayesha  Faisalabad       Mocha  Medium         2    550   1100
# 4      1005   Hassan      Multan   Americano   Large         4    400   1600
# 5      1006   Zainab      Lahore       Latte  Medium         1    450    450
# 6      1007    Usman     Karachi    Espresso   Small         5    350   1750
# 7      1008   Maryam   Islamabad  Flat White   Large         2    600   1200
# 8      1009    Bilal    Peshawar  Cappuccino   Small         3    500   1500
# 9      1010   Fatima      Quetta       Mocha  Medium         2    550   1100
#
#     Order Type
# 0  Small Order
# 1  Small Order
# 2  Small Order
# 3  Small Order
# 4   Bulk Order
# 5  Small Order
# 6   Bulk Order
# 7  Small Order
# 8  Small Order
# 9  Small Order
